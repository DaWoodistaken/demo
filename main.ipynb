# %%
# --default-timeout parametresi ile pip'e beklemesini söylüyoruz
# !pip install --default-timeout=1000 "mcp[cli]"
# Out:
# Requirement already satisfied: mcp[cli] in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (1.23.1)
# Requirement already satisfied: anyio>=4.5 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (4.8.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.4.0)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (2.7.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (2.12.5)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.35.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (1.0.1)
# Requirement already satisfied: typer>=0.16.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from mcp[cli]) (0.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sde25\appdata\roaming\python\python312\site-packages (from anyio>=4.5->mcp[cli]) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from anyio>=4.5->mcp[cli]) (1.3.1)
# Requirement already satisfied: certifi in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.1->mcp[cli]) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.1->mcp[cli]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp[cli]) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp[cli]) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp[cli]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.22.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp[cli]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp[cli]) (2.41.5)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (46.0.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.16.0->mcp[cli]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.16.0->mcp[cli]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.16.0->mcp[cli]) (13.9.4)
# Requirement already satisfied: colorama in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from click>=8.0.0->typer>=0.16.0->mcp[cli]) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer>=0.16.0->mcp[cli]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer>=0.16.0->mcp[cli]) (2.19.1)
# Requirement already satisfied: pycparser in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (2.22)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.16.0->mcp[cli]) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile my_demo_server.py
from mcp.server.fastmcp import FastMCP
import json

# Initialize Server
mcp = FastMCP("Enterprise Demo System")

# --- MOCK DATABASE (Simulation) ---
# In a real scenario, this would be a SQL Database or an external CRM API.
employee_db = {
    "emp_101": {
        "name": "Alice Johnson",
        "role": "Senior Developer",
        "department": "Engineering",
        "last_login": "2024-12-08 09:15:00",
        "access_level": "Admin"
    },
    "emp_102": {
        "name": "Bob Smith",
        "role": "Marketing Specialist",
        "department": "Marketing",
        "last_login": "2024-12-07 14:30:00",
        "access_level": "User"
    }
}

# --- PART 1: RESOURCES ---
# REALISTIC SCENARIO: 
# The model needs to "look up" a specific user's profile from the database.
# We use a URI template: memodb://employees/{user_id}

@mcp.resource("memodb://employees/{user_id}")
def get_employee_profile(user_id: str) -> str:
    """
    Retrieves the full profile of an employee by their ID.
    Returns JSON formatted string for the model to parse.
    """
    user_data = employee_db.get(user_id)
    
    if user_data:
        return json.dumps(user_data, indent=2)
    else:
        return "Error: Employee not found in the database."

# --- PART 2: TOOLS ---
# Scenario: HR or IT Action tools

@mcp.tool()
def calculate_bonus(salary: float, performance_score: int) -> float:
    """Calculates yearly bonus based on performance (1-5)."""
    if performance_score >= 5:
        return salary * 0.20
    elif performance_score >= 3:
        return salary * 0.10
    return 0.0

@mcp.tool()
def reset_password(user_id: str) -> str:
    """Resets the password for a specific user and generates a temporary one."""
    if user_id in employee_db:
        # Simulation of a password reset logic
        return f"SUCCESS: Password for {employee_db[user_id]['name']} has been reset. Temp pass: Xy9#mP2!"
    return "FAILED: User ID not found."

# --- PART 3: PROMPTS ---
# Standardized HR Workflow

@mcp.prompt()
def create_onboarding_plan(user_id: str) -> str:
    """Generates an onboarding checklist for a new employee based on their ID."""
    # The prompt function can also use internal logic to fetch data if needed,
    # or simply ask the model to use the Resource first.
    return f"""
    Please create an Onboarding Plan for the employee with ID: {user_id}.
    
    First, READ the employee's profile using the 'memodb://employees/{user_id}' resource.
    Then, based on their 'role' and 'department', generate a Day 1 checklist.
    """

if __name__ == "__main__":
    mcp.run()
# Out:
# Overwriting my_demo_server.py

# %%
# %pip install npx
# Out:
# Collecting npxNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading npx-0.1.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\sde25\appdata\local\programs\python\python312\lib\site-packages (from npx) (2.0.2)
# Downloading npx-0.1.6-py3-none-any.whl (10 kB)
# Installing collected packages: npx
# Successfully installed npx-0.1.6

# %%
#npx @modelcontextprotocol/inspector python my_demo_server.py
